# %%
import re
import pandas as pd

# %%
file = open('WhatsApp Chat with AIML .txt', 'r', encoding='utf-8')

# %%
data = file.read()

# %%
print(data)
# Out:
# 27/01/2025, 11:01 am - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 27/01/2025, 10:19 am - Adithya Cbit created group "AIML "
# 27/01/2025, 11:01 am - You joined using this group's invite link
# 27/01/2025, 11:08 am - +91 82477 46733 joined using this group's invite link
# 27/01/2025, 11:08 am - +91 98661 14779 joined using this group's invite link
# 27/01/2025, 11:22 am - +91 91542 65359 joined using this group's invite link
# 27/01/2025, 11:39 am - +91 86882 82089 joined using this group's invite link
# 27/01/2025, 12:08 pm - +91 91331 15115 joined using this group's invite link
# 27/01/2025, 12:08 pm - +91 63056 91016 joined using this group's invite link
# 27/01/2025, 12:09 pm - +91 63019 92861 joined using this group's invite link
# 27/01/2025, 12:10 pm - +91 97016 53366 joined using this group's invite link
# 27/01/2025, 12:10 pm - +91 93963 95008 joined using this group's invite link
# 27/01/2025, 12:13 pm - +91 72079 42111 joined using this group's invite link
# 27/01/2025, 12:13 pm - +91 93988 95670 joined using this group's invite link
# 27/01/2025, 12:16 pm - +91 85229 12720 joined using this group's invite link
# 27/01/2025, 12:17 pm - Rehaan Cbit joined using this group's invite link
# 27/01/2025, 12:21 pm - +91 76718 57689 joined using this group's invite link
# 27/01/2025, 12:25 pm - Bharath Cbit joined using this group's invite link
# 27/01/2025, 1:07 pm - +91 97034 06001: <Media omitted>
# 27/01/2025, 1:51 pm - +91 96762 11804 joined using this group's invite link
# 27/01/2025, 2:01 pm - Sampath joined using this group's invite link
# 27/01/2025, 2:57 pm - +91 73967 15060 joined using this group's invite link
# 28/01/2025, 12:21 pm - Santhosh Cbit joined using this group's invite link
# 28/01/2025, 2:34 pm - +91 70954 48829 joined using this group's invite link
# 30/01/2025, 9:17 am - +91 99089 44055 joined using this group's invite link
# 30/01/2025, 9:18 am - +91 63013 55947 joined using this group's invite link
# 30/01/2025, 9:36 am - +91 97034 06001: <Media omitted>
# 30/01/2025, 9:38 am - ~ Anu💙 added ~ Aksh.--.-- .-
# 30/01/2025, 9:38 am - +91 63010 75427 joined using this group's invite link
# 30/01/2025, 9:39 am - ~ Sowmya Nihitha added ~ Maanasa Kotte
# 30/01/2025, 9:40 am - +91 62819 61291 joined using this group's invite link
# 30/01/2025, 9:45 am - ~ Anu💙 added ~ Jayasreerathod
# 30/01/2025, 3:23 pm - +91 97034 06001: https://pascscha.ch/info2/abTreePractice/
# 30/01/2025, 3:23 pm - +91 97034 06001: animation of Alpha Beta Pruning Alg👆
# 06/02/2025, 9:22 am - +91 97034 06001: <Media omitted>
# 06/02/2025, 11:39 am - +91 97034 06001: Class CRs are requested to come to CSE dept Library at 12:15 for CCC meeting of AIML theory and Lab
# 10/02/2025, 10:49 am - Raghupati Cbit: This message was deleted
# 10/02/2025, 12:21 pm - +91 97034 06001: <Media omitted>
# 13/02/2025, 4:22 pm - +91 97034 06001: Student( toastmasters club)  who approached me today morning regarding allotment of space for the event , pl meet Lakshmaiah sir reg the above said subject
# 18/02/2025, 12:53 pm - +91 97034 06001: CR pl call me
# 18/02/2025, 1:39 pm - Aakif Cbit added Ayman Cbit
# 18/02/2025, 1:56 pm - Ayman Cbit: This message was deleted
# 25/02/2025, 12:54 pm - +91 97034 06001: can i know how many students are present in the class
# 25/02/2025, 12:57 pm - +91 97034 06001: come to lab 3
# 25/02/2025, 1:17 pm - Ayman Cbit added Neeraj
# 25/02/2025, 1:25 pm - +91 97034 06001: <Media omitted>
# 25/02/2025, 1:28 pm - +91 97034 06001: <Media omitted>
# 25/02/2025, 1:46 pm - +91 97034 06001: https://drive.google.com/drive/folders/1d2FlrDM65Ew1SQnDQYqcW6y6thg2oBOc?usp=sharing
# 25/02/2025, 1:47 pm - +91 97034 06001: Batch 3 folder
# 25/02/2025, 3:49 pm - Rehaan Cbit added Yash Rijhwani
# 10/03/2025, 11:19 am - +91 63019 92861: AIML programs
# 1.A*:water jug
# 2.A*:mesh
# 3.A*:Graphs
# 4.8 tiles using A*
# 5.CSP-Map coloring,
# 6.CSP:8queens
# 7.Alpha beta pruning
# 8.Linear regression
# 10/03/2025, 11:33 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:48 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:48 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:48 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:49 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:49 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:49 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:49 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:49 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:50 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:53 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 9:54 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 10:02 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 10:02 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 10:04 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 10:09 am - +91 97034 06001: <Media omitted>
# 13/03/2025, 11:06 am - +91 97034 06001: <Media omitted>
# 18/03/2025, 10:55 pm - Aakif Cbit: This message was deleted
# 23/03/2025, 3:32 pm - Rehaan Cbit: This message was deleted
# 24/03/2025, 9:32 am - +91 97034 06001: <Media omitted>
# 24/03/2025, 10:22 am - +91 97034 06001: <Media omitted>
# 24/03/2025, 10:23 am - +91 97034 06001: changed questions
# 24/03/2025, 10:25 am - +91 97034 06001: https://drive.google.com/drive/folders/1ZLk56v-UA-jPJOlAC_KIHXh5xgDchHTF?usp=sharing
# 24/03/2025, 10:25 am - +91 97034 06001: submit your assignment 1 in this link
# 24/03/2025, 10:26 am - +91 97034 06001: name of the file should be rollnum
# 24/03/2025, 10:27 am - +91 97034 06001: handwritten assignment has to be scanned and convert it into pdf , then upload
# 24/03/2025, 10:27 am - +91 97034 06001: deadline is today night 12:00 pm
# 24/03/2025, 10:31 am - +91 97034 06001: <Media omitted>
# 24/03/2025, 10:31 am - +91 97034 06001: modified unit 3, part 3. go through it
# 24/03/2025, 11:30 am - +91 97034 06001: <Media omitted>
# 25/03/2025, 12:27 pm - +91 97034 06001: Dear students please come to lab for class. Complete ridge and lasso
# 25/03/2025, 12:28 pm - +91 97034 06001: Already programs are shared in the group
# 25/03/2025, 12:43 pm - +91 97034 06001: Don’t come, i take class today
# 27/03/2025, 9:09 am - +91 97034 06001: Dear students, today after my topic in the class , slip test 2 will be conducted
# 29/03/2025, 3:19 pm - +91 97034 06001: <Media omitted>
# 03/04/2025, 10:01 am - +91 97034 06001: <Media omitted>
# 03/04/2025, 10:01 am - +91 97034 06001: <Media omitted>
# 03/04/2025, 10:01 am - +91 97034 06001: <Media omitted>
# 03/04/2025, 11:31 am - +91 97034 06001: <Media omitted>
# 08/04/2025, 12:58 pm - +91 97034 06001: Come to lab and complete your programs

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
pattern = r'\d{1,2}/\d{1,2}/\d{4},\s\d{1,2}:\d{2}\s(?:am|pm)\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Adithya Cbit created group "AIML "\n',
#  "You joined using this group's invite link\n",
#  "+91 82477 46733 joined using this group's invite link\n",
#  "+91 98661 14779 joined using this group's invite link\n",
#  "+91 91542 65359 joined using this group's invite link\n",
#  "+91 86882 82089 joined using this group's invite link\n",
#  "+91 91331 15115 joined using this group's invite link\n",
#  "+91 63056 91016 joined using this group's invite link\n",
#  "+91 63019 92861 joined using this group's invite link\n",
#  "+91 97016 53366 joined using this group's invite link\n",
#  "+91 93963 95008 joined using this group's invite link\n",
#  "+91 72079 42111 joined using this group's invite link\n",
#  "+91 93988 95670 joined using this group's invite link\n",
#  "+91 85229 12720 joined using this group's invite link\n",
#  "Rehaan Cbit joined using this group's invite link\n",
#  "+91 76718 57689 joined using this group's invite link\n",
#  "Bharath Cbit joined using this group's invite link\n",
#  '+91 97034 06001: <Media omitted>\n',
#  "+91 96762 11804 joined using this group's invite link\n",
#  "Sampath joined using this group's invite link\n",
#  "+91 73967 15060 joined using this group's invite link\n",
#  "Santhosh Cbit joined using this group's invite link\n",
#  "+91 70954 48829 joined using this group's invite link\n",
#  "+91 99089 44055 joined using this group's invite link\n",
#  "+91 63013 55947 joined using this group's invite link\n",
#  '+91 97034 06001: <Media omitted>\n',
#  '~\u202fAnu💙 added ~\u202fAksh.--.-- .-\n',
#  "+91 63010 75427 joined using this group's invite link\n",
#  '~\u202fSowmya Nihitha added ~\u202fMaanasa Kotte\n',
#  "+91 62819 61291 joined using this group's invite link\n",
#  '~\u202fAnu💙 added ~\u202fJayasreerathod\n',
#  '+91 97034 06001: https://pascscha.ch/info2/abTreePractice/\n',
#  '+91 97034 06001: animation of Alpha Beta Pruning Alg👆\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: Class CRs are requested to come to CSE dept Library at 12:15 for CCC meeting of AIML theory and Lab\n',
#  'Raghupati Cbit: This message was deleted\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: Student( toastmasters club)  who approached me today morning regarding allotment of space for the event , pl meet Lakshmaiah sir reg the above said subject\n',
#  '+91 97034 06001: CR pl call me\n',
#  'Aakif Cbit added Ayman Cbit\n',
#  'Ayman Cbit: This message was deleted\n',
#  '+91 97034 06001: can i know how many students are present in the class\n',
#  '+91 97034 06001: come to lab 3\n',
#  'Ayman Cbit added Neeraj\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: https://drive.google.com/drive/folders/1d2FlrDM65Ew1SQnDQYqcW6y6thg2oBOc?usp=sharing\n',
#  '+91 97034 06001: Batch 3 folder\n',
#  'Rehaan Cbit added Yash Rijhwani\n',
#  '+91 63019 92861: AIML programs\n1.A*:water jug\n2.A*:mesh\n3.A*:Graphs\n4.8 tiles using A*\n5.CSP-Map coloring,\n6.CSP:8queens\n7.Alpha beta pruning\n8.Linear regression\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  'Aakif Cbit: This message was deleted\n',
#  'Rehaan Cbit: This message was deleted\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: changed questions\n',
#  '+91 97034 06001: https://drive.google.com/drive/folders/1ZLk56v-UA-jPJOlAC_KIHXh5xgDchHTF?usp=sharing\n',
#  '+91 97034 06001: submit your assignment 1 in this link\n',
#  '+91 97034 06001: name of the file should be rollnum\n',
#  '+91 97034 06001: handwritten assignment has to be scanned and convert it into pdf , then upload\n',
#  '+91 97034 06001: deadline is today night 12:00 pm\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: modified unit 3, part 3. go through it\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: Dear students please come to lab for class. Complete ridge and lasso\n',
#  '+91 97034 06001: Already programs are shared in the group\n',
#  '+91 97034 06001: Don’t come, i take class today\n',
#  '+91 97034 06001: Dear students, today after my topic in the class , slip test 2 will be conducted\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001: <Media omitted>\n',
#  '+91 97034 06001
#  '25/02/2025, 1:47 pm - ',
#  '25/02/2025, 3:49 pm - ',
#  '10/03/2025, 11:19 am - ',
#  '10/03/2025, 11:33 am - ',
#  '13/03/2025, 9:48 am - ',
#  '13/03/2025, 9:48 am - ',
#  '13/03/2025, 9:48 am - ',
#  '13/03/2025, 9:49 am - ',
#  '13/03/2025, 9:49 am - ',
#  '13/03/2025, 9:49 am - ',
#  '13/03/2025, 9:49 am - ',
#  '13/03/2025, 9:49 am - ',
#  '13/03/2025, 9:50 am - ',
#  '13/03/2025, 9:53 am - ',
#  '13/03/2025, 9:54 am - ',
#  '13/03/2025, 10:02 am - ',
#  '13/03/2025, 10:02 am - ',
#  '13/03/2025, 10:04 am - ',
#  '13/03/2025, 10:09 am - ',
#  '13/03/2025, 11:06 am - ',
#  '18/03/2025, 10:55 pm - ',
#  '23/03/2025, 3:32 pm - ',
#  '24/03/2025, 9:32 am - ',
#  '24/03/2025, 10:22 am - ',
#  '24/03/2025, 10:23 am - ',
#  '24/03/2025, 10:25 am - ',
#  '24/03/2025, 10:25 am - ',
#  '24/03/2025, 10:26 am - ',
#  '24/03/2025, 10:27 am - ',
#  '24/03/2025, 10:27 am - ',
#  '24/03/2025, 10:31 am - ',
#  '24/03/2025, 10:31 am - ',
#  '24/03/2025, 11:30 am - ',
#  '25/03/2025, 12:27 pm - ',
#  '25/03/2025, 12:28 pm - ',
#  '25/03/2025, 12:43 pm - ',
#  '27/03/2025, 9:09 am - ',
#  '29/03/2025, 3:19 pm - ',
#  '03/04/2025, 10:01 am - ',
#  '03/04/2025, 10:01 am - ',
#  '03/04/2025, 10:01 am - ',
#  '03/04/2025, 11:31 am - ',
#  '08/04/2025, 12:58 pm - ']

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates_clean})

df['datetime'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p - ')
df = df.drop(['message_date'], axis=1)
df.rename(columns={'datetime': 'date'}, inplace=True)

# %%
df.sample(10)
# Out:
#                                          user_message                date
# 74  +91 97034 06001: submit your assignment 1 in t... 2025-03-24 10:25:00
# 59                 +91 97034 06001: <Media omitted>\n 2025-03-13 09:49:00
# 37                 +91 97034 06001: <Media omitted>\n 2025-02-10 12:21:00
# 82  +91 97034 06001: Already programs are shared i... 2025-03-25 12:28:00
# 85                 +91 97034 06001: <Media omitted>\n 2025-03-29 15:19:00
# 10  +91 97016 53366 joined using this group's invi... 2025-01-27 12:10:00
# 67                 +91 97034 06001: <Media omitted>\n 2025-03-13 11:06:00
# 52                 +91 97034 06001: <Media omitted>\n 2025-03-13 09:48:00
# 56                 +91 97034 06001: <Media omitted>\n 2025-03-13 09:49:00
# 75  +91 97034 06001: name of the file should be ro... 2025-03-24 10:26:00

# %%
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2025-01-27 11:01:00
# 1               Adithya Cbit created group "AIML "\n 2025-01-27 10:19:00
# 2        You joined using this group's invite link\n 2025-01-27 11:01:00
# 3  +91 82477 46733 joined using this group's invi... 2025-01-27 11:08:00
# 4  +91 98661 14779 joined using this group's invi... 2025-01-27 11:08:00

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group Notification')
        messages.append(entry[0])
df['users'] = users
df['message'] = messages
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15192\2692554625.py:4: SyntaxWarning: invalid escape sequence '\w'
#   entry = re.split('([\w\W]+?):\s', message)
#                                         user_message                date  \
# 0  Messages and calls are end-to-end encrypted. N... 2025-01-27 11:01:00
# 1               Adithya Cbit created group "AIML "\n 2025-01-27 10:19:00
# 2        You joined using this group's invite link\n 2025-01-27 11:01:00
# 3  +91 82477 46733 joined using this group's invi... 2025-01-27 11:08:00
# 4  +91 98661 14779 joined using this group's invi... 2025-01-27 11:08:00
#
#                 users                                            message
# 0  group Notification  Messages and calls are end-to-end encrypted. N...
# 1  group Notification               Adithya Cbit created group "AIML "\n
# 2  group Notification        You joined using this group's invite link\n
# 3  group Notification  +91 82477 46733 joined using this group's invi...
# 4  group Notification  +91 98661 14779 joined using this group's invi...

# %%
df.drop(columns=['user_message'], inplace=True)

# %%
df.sample(10)
# Out:
#                   date               users  \
# 51 2025-03-10 11:33:00     +91 97034 06001
# 44 2025-02-25 13:17:00  group Notification
# 18 2025-01-27 13:07:00     +91 97034 06001
# 37 2025-02-10 12:21:00     +91 97034 06001
# 52 2025-03-13 09:48:00     +91 97034 06001
# 21 2025-01-27 14:57:00  group Notification
# 24 2025-01-30 09:17:00  group Notification
# 23 2025-01-28 14:34:00  group Notification
# 42 2025-02-25 12:54:00     +91 97034 06001
# 19 2025-01-27 13:51:00  group Notification
#
#                                               message
# 51                                  <Media omitted>\n
# 44                          Ayman Cbit added Neeraj\n
# 18                                  <Media omitted>\n
# 37                                  <Media omitted>\n
# 52                                  <Media omitted>\n
# 21  +91 73967 15060 joined using this group's invi...
# 24  +91 99089 44055 joined using this group's invi...
# 23  +91 70954 48829 joined using this group's invi...
# 42  can i know how many students are present in th...
# 19  +91 96762 11804 joined using this group's invi...

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date               users  \
# 0 2025-01-27 11:01:00  group Notification
# 1 2025-01-27 10:19:00  group Notification
# 2 2025-01-27 11:01:00  group Notification
# 3 2025-01-27 11:08:00  group Notification
# 4 2025-01-27 11:08:00  group Notification
#
#                                              message  year
# 0  Messages and calls are end-to-end encrypted. N...  2025
# 1               Adithya Cbit created group "AIML "\n  2025
# 2        You joined using this group's invite link\n  2025
# 3  +91 82477 46733 joined using this group's invi...  2025
# 4  +91 98661 14779 joined using this group's invi...  2025

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

# %%
df.sample(7)
# Out:
#                   date               users  \
# 83 2025-03-25 12:43:00     +91 97034 06001
# 88 2025-04-03 10:01:00     +91 97034 06001
# 63 2025-03-13 10:02:00     +91 97034 06001
# 4  2025-01-27 11:08:00  group Notification
# 14 2025-01-27 12:16:00  group Notification
# 32 2025-01-30 15:23:00     +91 97034 06001
# 52 2025-03-13 09:48:00     +91 97034 06001
#
#                                               message  year    month  day  \
# 83                   Don’t come, i take class today\n  2025    March   25
# 88                                  <Media omitted>\n  2025    April    3
# 63                                  <Media omitted>\n  2025    March   13
# 4   +91 98661 14779 joined using this group's invi...  2025  January   27
# 14  +91 85229 12720 joined using this group's invi...  2025  January   27
# 32        https://pascscha.ch/info2/abTreePractice/\n  2025  January   30
# 52                                  <Media omitted>\n  2025    March   13
#
#     hour  minute
# 83    12      43
# 88    10       1
# 63    10       2
# 4     11       8
# 14    12      16
# 32    15      23
# 52     9      48
